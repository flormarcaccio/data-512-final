# %% [markdown]
# # Gender (In)Equality in Sports
# ##### DATA 512 A Au 20: Human-Centered Data Science
# *Florencia Marcaccio*

# %% [markdown]
# ## Table of Contents
# 1. [Motivation and problem statement](#motivation)
# 2. [Background/Related Work](#background)
# 3. [Data](#data)
# 4. [Research questions and/or hypotheses](#research_questions)
# 5. [Metodology](#metodology)
# 6. [Data Pre-Processing](#preprocessing)
# 7. [Findings](#findings)
# 8. [Discussion](#discussion)
# 9. [Limitations](#limitations)
# 10. [Conclusion](#conclusion)

# %% [markdown]
# ## <a name="motivation"></a> 1. Motivation and problem statement
#
# The main goal of this project is to explore the relationship between gender and sports in the US.  I would like to understand if men have any advantages over women when it comes to institutional support. To narrow down the scope of this research, I will be focusing on collegiate sports, expecting that what I found here could be a fair representation of what is also happening on the professional level.
#
# Sports are a considerable aspect of college life, which influences many students' decisions on whether or not to attend a specific institution. Thus, I think it would be interesting to see if men and women teams are treated equally and fairly among US universities.
#
# After completing the project, I hope that I will learn whether women are given the same opportunities as men when it comes to collegiate sports. I will be exploring not only the opportunities given to athletes, but also to women pursuing a careers in coaching. I will possibly obtain critical insights that can also be associated with professional sports, to be explored in a later analysis.

# %% [markdown]
# ## <a name="background"></a> 2. Background/Related Work
#
# Girls' and women's participation in US sports is an issue that was brought to attention many years ago ([Do You Know the Factors Influencing Girls’ Participation in Sports?](https://www.womenssportsfoundation.org/do-you-know-the-factors-influencing-girls-participation-in-sports/)). While it has improved -a lot thanks to the sucess and notoriety of women in sports like soccer, gymnastics and basketball-, there are still many aspects that are far behind men's sports.
#
# Most notably, the Women's Sports Foundation released its new national research report, ["Chasing Equity: The Triumphs, Challenges and Opportunities in Sports for Girls and Women,"](https://www.womenssportsfoundation.org/articles_and_report/chasing-equity-the-triumphs-challenges-and-opportunities-in-sports-for-girls-and-women/) which I think perfectly explains the current state of girls' and women's sports. The report covers many topics: participation opportunities, limitations, the role of Title IX, pay equity and equal treatment issues of women working in sports, and the media coverage of women's sports.
#
# In addition, because of the quality of the data collected by the Equity in Athletics survey, there are several papers and articles that reference this dataset in their analysis of participation equality in sports ([Examination of Gender Equity and Female Participation in Sport., Joshua A. Senne (2016)](https://thesportjournal.org/article/examination-of-gender-equity-and-female-participation-in-sport/) and  [A Comparison Study of the Perceptions of Athletic Administrators towards Gender Equity in the CCCU and NCCCU Schools. Martha L. Marra (2016)](https://thesportjournal.org/article/a-comparison-study-of-the-perceptions-of-athletic-administrators-towards-gender-equity-in-the-cccu-and-ncccu-schools/), among others), usually focusing on one particular division classification.

# %% [markdown]
# ## <a name="data"></a> 3. Data
#
#
# The dataset I'll use for this project contains data of US educational institutions with athletic programs that received federal student financial aid for the 2018-19 academic year. It has data on students' athletic participation, and staffing, revenues, and expenses by men's and women's teams.
#
# The dataset can be found in the [Download Data](https://ope.ed.gov/athletics/#/datafile/list) page of the [Equity in Athletics Data Analysis](https://ope.ed.gov/athletics/) website. The chosen data can be found under the year 2019, with the title "All data combined for academic year 2018-19". The data downloaded is already in this repository: ["EADA_2019.xlsx"](data/EADA_2019.xlsx) (data) and ["EADA_2019.doc"](data/EADA_2019.doc) (data description). For more information on each field, the actual [survey](https://surveys.ope.ed.gov/athletics/#/read-only-survey/-1/blank?printFormId=1) is also publically available.
# While there is no specified license, the dataset belongs under the [Equity in Athletics Disclosure Act](https://www2.ed.gov/finaid/prof/resources/athletics/eada.html) and was released to the public by the US Department of Education.
#
# This dataset is suitable for addressing the project goal as I can link the amount of resources and financial aid that women's and men's teams receive with how much university support they have. This will potentially disclose any unfair or biased treatment.
#
# One possible ethics issue that I see from using this dataset is that future students might be discouraged from even trying to pursue a career in sports if the analysis outcome is very pessimistic. However, if an unfair treatment is found, I think showcasing the findings is the key to start having the conversation about how to revert the situation.

# %% [markdown]
# ## <a name="research_questions"></a> 4. Research questions and/or hypotheses
#
# I have three main hypothesis that I will be analyzing in this project:
#
# 1. **H1: Students in women's teams receive less financial aid than participants in men's teams.**
#
#     1.1 Is there a relationship between financial aid and recruiting expenses, revenue and total expenses for women's teams?
#     1.2 Is there any difference between the amount of financial aid given to students in men's teams and the financial aid per participant's in women's teams?
#     1.3 Does having a men's football team affect the ratio of of financial aid given to women's teams?
#
#
# 2. **H2: Participation in sports is different between men and women.**
#
#
# 3. **H3: Women's teams are not given the same resources in terms of coaching staff.**
#
#     3.1 Is there a difference in the number of coaches (head and assistant) between women and men's teams?
#     3.2 What percentage of head/assistant coaches in men's teams are women, and what percentage of head/assistant coaches in women's teams are men?
#     3.3 Is there a difference in salary between coaches in women's teams vs coaches in men's teams?

# %% [markdown]
# ## <a name="metodology"></a> 5. Methodology
#
# I will first subset the data with the institutions I'm interested in. To have a set of institutions that give a fairly similar importance to sports, I will focus my analysis only on institutions that participate in NCAA divisions. To clean and pre-process the data, I will be using the Pandas package. To answer each hypothesis's questions, I will be using a mixture of  statistical analysis and data visualizations with Matplotlib and Seaborn.
#
# For the first hypothesis, I will be using scatterplots and a correlation heatmap for questions 1.1. I'm especially interested to see the correlation between the financial aid per participant for women's team and the other descriptive variables (recruiting expenses, revenue, total expenses), as it should present us with some evidence about the importance of athletic financial aid. For question 1.2-1.3, I will be using a mixture of distribution plots with one and two-sample t-test analysis. The last question could be quite interesting, as I believe that institutions that play football probably tend to give more attention and resources to that sport.
#
# For the other two hypothesis I will again be using a mixture between distribution plots and t-tests. The statistical testing will help determine if there is evidence to say that there is a difference in the percentage of female participating in sports, as well determine payment inequality.
#
# While the dataset does not have that many observations, I believe it will not be an issue as I will only be doing EDA and statisticas analysis that can work with smaller data.

# %% [markdown]
# ## <a name="preprocessing"></a> 6. Data Pre-Processing

# %% [markdown]
# ### Importing libraries for cleaning and for analysis

# %%
import pandas as pd
from matplotlib import pyplot as plt
from scipy import stats
import seaborn as sn

# %% [markdown]
# ### Loading data

# %%
df = pd.read_excel('data/EADA_2019.xlsx')
df.shape
# Out:
# (2074, 4274)

# %%
df.head()
# Out:
#    unitid                     institution_name  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100706  University of Alabama in Huntsville
# 3  100724             Alabama State University
# 4  100751            The University of Alabama
#
#                         addr1_txt addr2_txt    city_txt state_cd  zip_text  \
# 0            4900 Meridian Street       NaN      Normal       AL   35762.0
# 1  Administration Bldg Suite 1070       NaN  Birmingham       AL   35294.0
# 2                 301 Sparkman Dr       NaN  Huntsville       AL   35899.0
# 3            915 S Jackson Street       NaN  Montgomery       AL   36104.0
# 4             739 University Blvd       NaN  Tuscaloosa       AL   35487.0
#
#    ClassificationCode                classification_name ClassificationOther  \
# 0                   2                NCAA Division I-FCS                 NaN
# ...

# %% [markdown]
# ### Cleaning

# %% [markdown]
# For easier handling, I will reduce the dataset to the fields I will be using during the analysis. For a description of all variables please refer to [the documentation](data/EADA_2019.doc).

# %%
df = df[['unitid', 'institution_name', 'city_txt', 'state_cd', 'zip_text', 'ClassificationCode', 'classification_name',
   'sector_cd', 'sector_name', 'EFMaleCount', 'EFFemaleCount', 'EFTotalCount', 'STUDENTAID_MEN', 'STUDENTAID_WOMEN',
   'STUDENTAID_TOTAL', 'IL_PARTIC_MEN', 'IL_PARTIC_WOMEN', 'RECRUITEXP_MEN', 'RECRUITEXP_WOMEN', 'IL_EXP_MEN',
   'IL_EXP_WOMEN', 'IL_REV_MEN', 'IL_REV_WOMEN', 'HDCOACH_SALARY_MEN', 'HDCOACH_SALARY_WOMEN', 
   'IL_MEN_FTHEADCOACH_MALE', 'IL_MEN_PTHEADCOACH_MALE','IL_MEN_FTHEADCOACH_FEM', 'IL_MEN_PTHEADCOACH_FEM',
   'IL_WOMEN_FTHDCOACH_MALE', 'IL_WOMEN_PTHDCOACH_MALE', 'IL_WOMEN_FTHDCOACH_FEM', 'IL_WOMEN_PTHDCOACH_FEM', 
   'IL_MEN_FTASCOACH_MALE', 'IL_MEN_PTASCOACH_MALE', 'IL_MEN_FTASSTCOACH_FEM', 'IL_MEN_PTASSTCOACH_FEM', 
   'IL_WOMEN_FTASCOACH_MALE', 'IL_WOMEN_PTASCOACH_MALE', 'IL_WOMEN_FTASTCOACH_FEM', 'IL_WOMEN_PTASTCOACH_FEM']]
df.columns = map(str.lower, df.columns)
df.shape
# Out:
# (2074, 41)

# %% [markdown]
# Assigning a zero to null values in numeric features.

# %%
cols_updt = ['studentaid_men', 'studentaid_women', 'recruitexp_men' , 'recruitexp_women', 'hdcoach_salary_men',
             'il_men_ftheadcoach_male', 'il_men_ptheadcoach_male', 'il_men_ftheadcoach_fem', 'il_men_ptheadcoach_fem',
             'il_men_ftascoach_male', 'il_men_ptascoach_male', 'il_men_ftasstcoach_fem', 'il_men_ptasstcoach_fem',
             'il_women_ftascoach_male', 'il_women_ptascoach_male', 'il_women_ftastcoach_fem', 'il_women_ptastcoach_fem']
df.update(df[cols_updt].fillna(0))

# %% [markdown]
# Keeping institutions that satisfy specific criteria:

# %%
#Institutions in the NCAA divisions
df = df[df.classificationcode.isin(list(range(1,8)))]
#Institutions that declared students
df = df[df.eftotalcount > 0]
#Institutions that declared participants in men and women's teams
df = df[df.il_partic_men > 0]
df = df[df.il_partic_women > 0]
#Institutions that received financial aid
df = df[df.studentaid_total > 0]
#Institutions from the US
df = df[~df.state_cd.isna()]

df.shape
# Out:
# (654, 41)

# %% [markdown]
# Creating fields for the recruiting expenses, total revenue, total expenses and athletic financial aid per participant in men and women's teams, and a field with the difference between financial aid per participant by gender.

# %%
df['recruitexp_participant_women'] = df['recruitexp_women']/df['il_partic_women']
df['recruitexp_participant_men'] = df['recruitexp_men']/df['il_partic_men']

df['rev_participant_women'] = df['il_rev_women']/df['il_partic_women']
df['rev_participant_men'] = df['il_rev_men']/df['il_partic_men']

df['exp_participant_women'] = df['il_exp_women']/df['il_partic_women']
df['exp_participant_men'] = df['il_exp_men']/df['il_partic_men']

df['aid_participant_women'] = df['studentaid_women']/df['il_partic_women']
df['aid_participant_men'] = df['studentaid_men']/df['il_partic_men']
df['diff_aid_participant'] = df['aid_participant_men']-df['aid_participant_women']

# %% [markdown]
# Creating a field for the difference in number of participants in men and women's teams.

# %%
df['diff_participation'] = df['il_partic_men'] - df['il_partic_women']

# %% [markdown]
# Creating fields for the total number of head and assistant coaches in men and women's teams, total number of coaches (head+assistant), and the difference in total number of coaches between men's and women's teams.

# %%
df['men_num_hdcoaches'] = df['il_men_ftheadcoach_male']+df['il_men_ptheadcoach_male']+df['il_men_ftheadcoach_fem']+df['il_men_ptheadcoach_fem']
df['women_num_hdcoaches'] = df['il_women_fthdcoach_male']+df['il_women_pthdcoach_male']+df['il_women_fthdcoach_fem']+df['il_women_pthdcoach_fem']
df['men_num_ascoaches'] = df['il_men_ftascoach_male']+df['il_men_ptascoach_male']+df['il_men_ftasstcoach_fem']+df['il_men_ptasstcoach_fem']
df['women_num_ascoaches'] = df['il_women_ftascoach_male']+df['il_women_ptascoach_male']+df['il_women_ftastcoach_fem']+df['il_women_ptastcoach_fem']

df['men_num_coaches'] = df['men_num_hdcoaches']+df['men_num_ascoaches']
df['women_num_coaches'] = df['women_num_hdcoaches']+df['women_num_ascoaches']

df['diff_num_coaches'] = df['men_num_coaches'] - df['women_num_coaches']

# %% [markdown]
# Students per coach in women and men's teams, and the difference between these two.

# %%
df['women_per_coach'] = df['il_partic_women']/df['women_num_coaches']
df['men_per_coach'] = df['il_partic_men']/df['men_num_coaches']
df['diff_students_per_coach'] = df['men_per_coach'] - df['women_per_coach']

# %% [markdown]
# Percentage of head and assistant coaches in men and women's teams by gender.

# %%
df['men_perc_femhdcoaches'] = (df['il_men_ftheadcoach_fem']+df['il_men_ptheadcoach_fem'])/df['men_num_hdcoaches']
df['women_perc_malehdcoaches'] = (df['il_women_fthdcoach_male']+df['il_women_pthdcoach_male'])/df['women_num_hdcoaches']
df['men_perc_femascoaches'] = (df['il_men_ftasstcoach_fem']+df['il_men_ptasstcoach_fem'])/df['men_num_ascoaches']
df['women_perc_maleascoaches'] = (df['il_women_ftascoach_male']+df['il_women_ptascoach_male'])/df['women_num_ascoaches']

# %% [markdown]
# Creating a field with the difference between the mean salary of head coaches in men's teams and the mean salary of head coaches in women's teams.

# %%
df['diff_salary'] = df['hdcoach_salary_men'] - df['hdcoach_salary_women']

# %% [markdown]
# ### Saving the data to a preprocessed file

# %%
df.to_csv("data/processed_data.csv")

# %% [markdown]
# ## <a name="findings"></a> 7. Findings

# %% [markdown]
# The required libraries were already loaded in the preprocessing stage.

# %% [markdown]
# ### Loading processed data

# %%
df = pd.read_csv('data/processed_data.csv')
df.shape
# Out:
# (654, 67)

# %% [markdown]
# After the prerpocessing stage, the dataset has 654 rows.

# %%
df.head()
# Out:
#    Unnamed: 0  unitid                     institution_name    city_txt  \
# 0           0  100654             Alabama A & M University      Normal
# 1           1  100663  University of Alabama at Birmingham  Birmingham
# 2           2  100706  University of Alabama in Huntsville  Huntsville
# 3           3  100724             Alabama State University  Montgomery
# 4           4  100751            The University of Alabama  Tuscaloosa
#
#   state_cd  zip_text  classificationcode                classification_name  \
# 0       AL   35762.0                   2                NCAA Division I-FCS
# 1       AL   35294.0                   1                NCAA Division I-FBS
# 2       AL   35899.0                   5  NCAA Division II without football
# 3       AL   36104.0                   2                NCAA Division I-FCS
# 4       AL   35487.0                   1                NCAA Division I-FBS
#
#    sector_cd              sector_name  ...  women_num_coaches  \
# ...

# %% [markdown]
# ### Creating reusable plotting functions

# %%
def single_distribution_plot(data, title_graph, x_label, png_name):
    fig, ax = plt.subplots(figsize=(10,6))
    plt.hist(data, color='purple')
    plt.title(title_graph, fontsize=20)
    plt.xlabel(x_label, fontsize=15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid()
    plot_name = 'graphs/'+png_name+'.png'
    plt.savefig(plot_name , bbox_inches='tight')
    plt.show()

def dual_distribution_plot(data1, data2, title_graph, x_label, data1_label, data2_label, png_name):
    fig, ax = plt.subplots(figsize=(10,6))
    plt.hist(data1, density=True, histtype='barstacked', alpha=0.7, color='purple', label=data1_label)
    plt.hist(data2, density=True, histtype='barstacked', alpha=0.7, color='skyblue', label=data2_label)
    plt.legend(loc = 'upper right', fontsize=15)
    plt.title(title_graph, fontsize=20)
    plt.xlabel(x_label, fontsize=15)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.grid()
    plot_name = 'graphs/'+png_name+'.png'
    plt.savefig(plot_name , bbox_inches='tight')
    plt.show()

# %% [markdown]
# ### *Hypothesis 1: Students in women's teams receive less financial aid than participants in men's team's.*

# %% [markdown]
# ### 1.1 Is there a relationship between financial aid and recruiting expenses, revenue and total expenses for women's teams?

# %% [markdown]
# I do not want the numbers used in the analysis to be conditioned by the difference in number of students playing sports in each institution. Therefore, I will be using fields created in preprocessing that account for financial aid per participant, recruiting expenses per participant, revenue per participant and total expenses per participant. These four fields are defined for men and women's teams.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24,8))
fig.suptitle("Relationship between financial aid and recruiting expenses/revenue/total expenses per participants in women's teams", fontsize=20)
ax1.scatter(df['aid_participant_women'], df['recruitexp_participant_women'])
ax1.set_title('Financial aid vs Recruiting expenses per participant', fontsize=15)
ax1.set_xlabel("Financial aid per participant", fontsize=15)
ax1.set_ylabel("Recruiting expenses per participant", fontsize=15)
ax1.grid()

ax2.scatter(df['aid_participant_women'], df['rev_participant_women'])
ax2.set_title('Financial aid vs Revenue per participant', fontsize=15)
ax2.set_xlabel("Financial aid per participant", fontsize=15)
ax2.set_ylabel("Revenue per participant", fontsize=15)
ax2.grid()

ax3.scatter(df['aid_participant_women'], df['exp_participant_women'])
ax3.set_title('Financial aid vs Total expenses per participant', fontsize=15)
ax3.set_xlabel("Financial aid per participant", fontsize=15)
ax3.set_ylabel("Total expenses per participant", fontsize=15)
ax3.grid()

plt.savefig('graphs/financial_aid_relationships.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# When looking at women's teams, we can see that there is a positive linear relationship between the amount of financial aid per participant with the recruiting expenses, total revenue and total expenses per participant.

# %% [markdown]
# To corroborate this, I will look into the correlation between financial aid and the remaining three variables.

# %%
fig, ax = plt.subplots(figsize=(10, 10))
corrMatrix = df[['aid_participant_women', 'recruitexp_participant_women', 'rev_participant_women', 'exp_participant_women']].corr()
sn.heatmap(corrMatrix, annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.yticks(rotation=0, fontsize=15)
plt.xticks(fontsize=15)
plt.title("Correlation between financial variables per participant in women's teams", fontsize=20)

plt.savefig('graphs/financial_aid_correlations.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# From this, we can say that there is a correlation between the amount of athletic financial aid given to participants in women's teams and their expenses and revenues.

# %% [markdown]
# ### 1.2 Is there any difference between the amount of financial aid given to students in men's teams and the student aid for participant's in women's teams?

# %% [markdown]
# Knowing that financial aid plays an important role on the financial variables, I would like to know if there is a difference in the amount of aid given to students in women's sports with the aid given to participants in men's teams.

# %% [markdown]
# To do this, I will be looking at the 'diff_aid_participant' variable (financial aid per student in men's team - financial aid per student in women's team). If an instutition treats students in men and women's teams equally, you would assume that this variable should be close to zero.

# %%
df['diff_aid_participant'].describe()
# Out:
# count      654.000000
# mean        27.475753
# std       3250.657674
# min     -10766.175664
# 25%      -1536.443265
# 50%       -226.577890
# 75%       1249.927593
# max      17434.146752
# Name: diff_aid_participant, dtype: float64

# %% [markdown]
# From those statistics, we can see that the mean of the variable is quite close to zero, with a pretty high standard deviation. To complete this analysis, I will plot the distribution of the variable and perform a one-sample t-test under the null hypothesis that the mean difference is zero.

# %%
data = df['diff_aid_participant']
title = "Difference of financial aid per participant by gender"
xlabel = "Financial aid difference"

single_distribution_plot(data, title, xlabel, 'financial_aid_difference_gender')

# %%
stats.ttest_1samp(df['diff_aid_participant'],0)
# Out:
# Ttest_1sampResult(statistic=0.2161559730511221, pvalue=0.828933675362348)

# %% [markdown]
# Because the p-value is greater than 0.05, I found no evidence to say that the financial aid given to students in women's teams is different to the aid given to participants in men's teams.

# %% [markdown]
# ### 1.3 Does having a men's football team affect the ratio of of financial aid given to women's teams?

# %% [markdown]
# After reading the articles in [Background/Related Work](#background) and knowing the importance of football in US institutions, I would like to explore the financial aid distribution from the previous question between institutions that have football agains the ones that don't.

# %% [markdown]
# I will first separate the dataset in the two subsets using the classification code. The codes 3, 5 and 7 represent the institutions in NCAA Divisions I, II and III with no football.

# %%
nofootball = df[df.classificationcode.isin([3,5,7])]['diff_aid_participant']
football = df[~df.classificationcode.isin([3,5,7])]['diff_aid_participant']

# %% [markdown]
# The variable I will be using for this analysis is diff_aid_participant, which the same as in question 1.2. I will plot the distribution of this variable for both subsets and perform a two-sample t-test under the null hypothesis that there is no difference between institutions that play football and the ones that don't.

# %%
data1 = football
data2 = nofootball
title = "Difference in financial aid per participant between students in men and women's teams"
xlabel = "Financial aid difference"
data1_label = 'Football'
data2_label = 'No football'

dual_distribution_plot(data1, data2, title, xlabel, data1_label, data2_label, 'financial_aid_difference_football')

# %%
stats.ttest_ind(nofootball, football)
# Out:
# Ttest_indResult(statistic=-11.353851553151324, pvalue=2.184318688973109e-27)

# %% [markdown]
# In question 1.2 we found that there was no evidence to say that institution give a different amount of financial aid to participants in women's sports in comparison to the financial aid given to students in men's teams. However, because the p-value of the last test was lower than 0.05, we have evidence to say that institution with football have a higher mean difference in financial aid by gender than institutions that don't play football. This means than, on average, institutions that play football assign higher financial aid per participant to students in men's teams.
# This difference in behavior can clearly be seen on the graph.

# %% [markdown]
# ### *Hypothesis 2: Participation in sports is different between men and women.*

# %% [markdown]
# When I talk about participation in sports, what I want to find out is if female students have the same opportunities as men in an institution. I assume opportunities are equal when an institution has an equal number of female and male students participating in sports.

# %% [markdown]
# I will plot the distribution of participants in men and women's teams and then perform a t-test. For the test, I have created in the data processing stage a field called diff_participation with the difference of participants by gender (men-women). The t-test is under the null hypothesis that participation is equal, so the mean difference of participants by gender is zero.

# %%
data1 = df['il_partic_women']
data2 = df['il_partic_men']
title = "Distribution of students participating in sports by gender"
xlabel = "Students in sports"
data1_label = "Female students participation"
data2_label = "Male students participation"

dual_distribution_plot(data1, data2, title, xlabel, data1_label, data2_label, 'participation_gender')

# %%
stats.ttest_1samp(df['diff_participation'],0)
# Out:
# Ttest_1sampResult(statistic=15.110552912301255, pvalue=1.850705454083261e-44)

# %% [markdown]
# Because the p-value is less than 0.05, I have evidence to reject the null hypothesis and sat that participation in sports by gender is not equal. This means that institutions don't have the same number of athletic positions available for both men and women.

# %% [markdown]
# ### *Hypothesis 3: Women's teams are not given the same resources in terms of coaching staff.*

# %% [markdown]
# ### 3.1 How many head coaches are there for women's and men's teams? How many assistant coaches for women's and men's teams?

# %% [markdown]
# I will first look at the difference in the total number of coaches using the field diff_num_coaches, which was created in preprocessing stage and has, for each institution, the difference between the total number of coaches in men's teams and the total number of coaches in women's teams. I will first look at the plot of this distribution and then perform a t-test under the null hypothesis that the mean difference in number of coaches is zero.

# %%
data = df['diff_num_coaches']
title = "Distribution of the difference in number of coaches between men and women's teams"
xlabel = "Difference in number of coaches coach"

single_distribution_plot(data, title, xlabel, 'diff_num_coaches')

# %%
stats.ttest_1samp(df['diff_num_coaches'],0)
# Out:
# Ttest_1sampResult(statistic=8.524648405995853, pvalue=1.062014386781708e-16)

# %% [markdown]
# Because p-value is less than 0.05, we can reject the null hypothesis that men and women's teams have the same number of coaches. However, this was expected after analyzing the second hypothesis in this project. We found evidence to say that there are more participants in men's sports, so it is reasonable that institutions have a higher number of coaches in men's teams.

# %% [markdown]
# To account for this, I will again look for the difference in coaches, but this time I will look at the number of participants per coach in women and men's teams. You would expect that institutions would assign a similar number of students to each coach, so the difference between students per coach in women and men's teams should be close to zero. The field diff_students_per_coach was calculated as the number of male participants per coach minus the female participants per coach. I will first plot this difference and then perform a t-test under the null hypothesis that the mean difference is zero.

# %%
data = df['diff_students_per_coach']
title = "Distribution of the difference in students per coach between men and women's teams"
xlabel = "Difference in students per coach"

single_distribution_plot(data, title, xlabel, 'diff_students_per_coach')

# %%
stats.ttest_1samp(df['diff_students_per_coach'],0)
# Out:
# Ttest_1sampResult(statistic=12.397068188940018, pvalue=7.611622762012326e-32)

# %% [markdown]
# The result from this test is quite interesting, as we can reject the null hypothesis of the difference being zero. However, as seen on the distribution, we have evidence to say that the difference is higher than zero, which means that the number of students per coach is higher in men's teams.

# %% [markdown]
# ### 3.2 What percentage of head/assistant coaches in men's teams are women, and what percentage of head/assistant coaches in women's teams are men?

# %% [markdown]
# From the previous question, I learned that women's teams have more coaches per participant than men's teams. So, now I would like to learn a bit more about the gender of the coaches and if there is a difference between the likelihood of women working in the coaching staff of men's teams and men working in women's teams.

# %% [markdown]
# First, I explore the head coaches. The men_perc_femhdcoaches variable has the percentage of female head coaches out of all the head coaches in men's teams, and the women_perc_malehdcoaches variable has the percentage of male head coaches out of all the head coaches in women's teams.

# %%
df['men_perc_femhdcoaches'].describe()
# Out:
# count    654.000000
# mean       0.035193
# std        0.075458
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        0.400000
# Name: men_perc_femhdcoaches, dtype: float64

# %%
df['women_perc_malehdcoaches'].describe()
# Out:
# count    654.000000
# mean       0.575176
# std        0.177342
# min        0.000000
# 25%        0.444444
# 50%        0.571429
# 75%        0.714286
# max        1.000000
# Name: women_perc_malehdcoaches, dtype: float64

# %%
data1 = df['men_perc_femhdcoaches']
data2 = df['women_perc_malehdcoaches']
title = "Distribution of percentage of male HD coaches in women's teams and female HD coaches in men's teams"
xlabel = "Percentage of coaches"
data1_label = "Female HD coaches in men's teams"
data2_label = "Male HD coaches in women's teams"

dual_distribution_plot(data1, data2, title, xlabel, data1_label, data2_label, 'hd_coaches_opportunities')

# %% [markdown]
# With the statistics and the distribution plot, there is a clear difference in opportunities for women in coaching positions in comparison to men. It is very unusual for female coaches to work as a had coach for men's teams. However, in over half of the institutions, at least 50% of head coaches for women's teams are men.

# %% [markdown]
# Now we explore assistant coaches using the variables men_perc_femascoaches and women_perc_maleascoaches:

# %%
df['men_perc_femascoaches'].describe()
# Out:
# count    652.000000
# mean       0.065517
# std        0.073191
# min        0.000000
# 25%        0.000000
# 50%        0.052632
# 75%        0.100000
# max        0.615385
# Name: men_perc_femascoaches, dtype: float64

# %%
df['women_perc_maleascoaches'].describe()
# Out:
# count    653.000000
# mean       0.469023
# std        0.159236
# min        0.000000
# 25%        0.375000
# 50%        0.478261
# 75%        0.565217
# max        1.000000
# Name: women_perc_maleascoaches, dtype: float64

# %%
data1 = df['men_perc_femascoaches']
data2 = df['women_perc_maleascoaches']
title = "Distribution of percentage of male assistant coaches in women's teams and female assistant coaches in men's teams"
xlabel = "Percentage of coaches"
data1_label = "Female assistant coaches in men's teams"
data2_label = "Male assistant coaches in women's teams"

dual_distribution_plot(data1, data2, title, xlabel, data1_label, data2_label, 'assistant_coaches_opportunities')

# %% [markdown]
# The same thing happens with assistant coaches. The opportunities for female assitant coaches are very few when comparing them to opportunities for male coaches.

# %% [markdown]
# ### 3.3 Is there a difference in salary between coaches in women's teams vs coaches in men's teams?

# %% [markdown]
# Form the mean salary of head coches in men and women's teams available in the dataset, I calculated the difference in the preprocessing stage (mean salary for a head coach in a men's team - mean salary for a head coach in a women's team). If all teams are given the same resources, you would expect this difference to be zero. I will look at the statistics, plot the distribution of the difference and perform a t-test under the null hypothesis that the difference in mean salaries is zero.

# %%
df['diff_salary'].describe()
# Out:
# count    6.540000e+02
# mean     1.397158e+05
# std      2.894625e+05
# min     -1.714100e+04
# 25%      7.173250e+03
# 50%      2.590750e+04
# 75%      9.171275e+04
# max      1.700985e+06
# Name: diff_salary, dtype: float64

# %%
data = df['diff_salary']
title = "Distribution of difference in salary per coach between men and women's teams"
xlabel = "Difference in salary per coach"

single_distribution_plot(data, title, xlabel, 'diff_salaries_gender')

# %%
stats.ttest_1samp(df['diff_salary'],0)
# Out:
# Ttest_1sampResult(statistic=12.343604239723767, pvalue=1.3051829261350006e-31)

# %% [markdown]
# Already from the plot we can see that the distribution is right skewed. This means that the difference usually has positive values, which indicate that the mean salary for coaches in men's teams tends to be higher than the salary for coaches in women's teams.
#
# To confirm this, because the p-value is lower than 0.05, we can reject the null hypothesis that the mean difference in salaries by men and women's teams is zero. From this sample, we can see that, on average, the anual salary for coaches in men's teams is ~ $140K higher than the salary of women's teams HD coaches.

# %% [markdown]
# ## <a name="discussion"></a> 8. Discussion

# %% [markdown]
# From this analysis, we can say that there is a strong positive correlation between the amount of financial aid given to students and the amount of expenses and revenue obtained for women’s teams. I believe it is important to understand that the amount of disbursed athletic financial aid could be essential for the teams’ bottom line.
#
# Once we have established the crucial role of financial aid, the next step is to identify if there is a difference in financial aid per participant given to men and women’s teams. We found no evidence of this when looking at the entire dataset. However, this changes when you break down the institutions on whether or not the university has football as one of their sports. There is statistical evidence to say that universities with football give more financial aid per participant to men’s teams. I believe this is important for incoming female students deciding between universities’ athletic programs, as they might be more likely to obtain a higher amount of financial aid in universities that do not play football.
#
# After doing the financial analysis per participant, another critical factor found is that there are fewer opportunities for women to participate in sports. This brings me back to the previous finding of no evidence to say that institutions assign less financial aid per participant (when taking into account all institutions and not looking at the effect of football). While there is no difference in disbursed aid per participant in men’s and women’s teams, that does not mean that it would be the same if the number of women participating in sports matches the men’s participation.
#
# For the final hypothesis, I explored the coaching resources given to women’s teams and the opportunities that women have after finishing their careers as athletes.
# What I found is that there are fewer students per coach in women’s teams. This means that there are more coaching positions available for women’s teams when adjusting for the number of students participating in sports. However, it is vital to note that these coaching positions are not necessarily for female coaches. On average, I found that a bit over 50% of coaches in women’s teams are male. In contrast, female coaches rarely have opportunities in the coaching staff for men’s teams.
# Also, I found a difference in the average annual salary for coaches in men’s and women’s teams, with salaries for head coaches in men's teams being approximately $140K higher. This could mean that universities tend to invest less in women’s sports and, thanks to what we found about the reduced opportunities for female coaches in men’s teams, we know that female coaches don’t have access to these higher salaries.
#
#
# Finally, I would say that there are apparent similarities with what is currently happening on a professional level. For example, the NSWL (National Soccer Women League) has 10 participating teams, while the MLS (Major League Soccer) has 26 teams. There are clearly fewer opportunities for women athletes to participate in the sport on a professional level. This is particularly interesting when considering that the US is the number one in women's soccer on an international level. If this is happening in a sport where women tend to perform better than men on an international level, you can expect this difference to exist in most sports. The finding of female coaches having fewer opportunities than male coaches also stands. Only 2 out of the 10 head coaches in the NSWL are women. Similarly, only 4 out of the 12 head coaches in the WNBA (Women's National Basketball Association) are women. Unsurprisingly, none of the head coaches in the men's leagues for these two sports are women.

# %% [markdown]
# ## <a name="limitations"></a> 9. Limitations

# %% [markdown]
# While I tried to reduce differences among institutions by choosing only the NCAA division participants, there are still differences between divisions I, II, and III institutions that are not considered for this analysis.
# Additionally, I understand that the dataset’s size might still be a cause of concern, even when I only used techniques that work with smaller sets. The reason why I didn't add data from other years was to avoid having multiple rows for the same institution, as that would possibly introduce noise to the data and might create issues with the independence between observations that is needed for the statistical tests.
# Finally, there is always the risk of biases in the data. As each institution provided the information,  there is no way to confirm its validity.

# %% [markdown]
# ## <a name="conclusion"></a> 10. Conclusion

# %% [markdown]
# Overall, the findings in this analysis are not the most encouraging to aspiring female athletes or coaches. Women still don't have the same opportunities as men in collegiate sports, and I was able to showcase parallels to the professional level in the Discussion section.
# Even though there has been a lot of talk in recent years about reducing the gender gap in sports thanks to the fantastic performance of female athletes, I would say that there is still a long road ahead to achieve gender equality in sports.
